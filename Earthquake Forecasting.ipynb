# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import matplotlib
df = pd.read_csv('desktop/database.csv')

# %%
df.dropna(subset=['Magnitude','Date', 'Latitude', 'Longitude'])
X = df[['Magnitude', 'Date', 'Latitude', 'Longitude']]
X
# Out:
#        Magnitude        Date  Latitude  Longitude
# 0            6.0  01/02/1965   19.2460   145.6160
# 1            5.8  01/04/1965    1.8630   127.3520
# 2            6.2  01/05/1965  -20.5790  -173.9720
# 3            5.8  01/08/1965  -59.0760   -23.5570
# 4            5.8  01/09/1965   11.9380   126.4270
# ...          ...         ...       ...        ...
# 23407        5.6  12/28/2016   38.3917  -118.8941
# 23408        5.5  12/28/2016   38.3777  -118.8957
# 23409        5.9  12/28/2016   36.9179   140.4262
# 23410        6.3  12/29/2016   -9.0283   118.6639
# 23411        5.5  12/30/2016   37.3973   141.4103
#
# [23412 rows x 4 columns]

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.style.use("ggplot")
X["Magnitude"].plot(color="purple")
plt.show()

# %%
K = df[['Latitude', 'Longitude']]
from sklearn.cluster import KMeans
K_Means = KMeans(n_clusters=2).fit(K)
K.plot.scatter(x='Latitude', y='Longitude', c='DarkBlue')
K_Means.predict(K)
K_clustering = K_Means.cluster_centers_
for i in range (0,2):
    plt.plot(K_clustering[i][0], K_clustering[i][1], 'ro')
plt.show()

# %%
distances = []
for i in range (1,16):
    K_Means = KMeans(n_clusters=i).fit(K)
    distances.append(K_Means.inertia_)
for i in range (0,15):
    plt.plot(i+1, distances[i], 'ro')
plt.show()

# %%
dates = []
magnitudes = []
count = 0
for i in range(0,23411):
    if (abs(-40-X.loc[i].at["Latitude"]) <= 6) and (abs(X.loc[i].at["Longitude"]-172) <= 6):
        dates.append(X.loc[i].at["Date"])
        magnitudes.append(X.loc[i].at["Magnitude"])
        count += 1
count
# Out:
# 133

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from sklearn.model_selection import train_test_split
y = magnitudes
X = pd.DataFrame()
X['ds'] = pd.to_datetime(dates, utc=True)
X['ds'] = X['ds'].dt.tz_localize(None)
X['y'] = y
prediction = Prophet()
prediction.fit(X)
future = prediction.make_future_dataframe(periods=240, freq='m')
forecast = prediction.predict(future)
figure = prediction.plot(forecast)
figure = prediction.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from sklearn.model_selection import train_test_split
y = magnitudes
X = pd.DataFrame()
X['ds'] = pd.to_datetime(dates, utc=True)
X['ds'] = X['ds'].dt.tz_localize(None)
X['y'] = y
prediction = Prophet()
prediction.fit(X)
future = prediction.make_future_dataframe(periods=240, freq='m')
forecast = prediction.predict(future)
figure = prediction.plot(forecast)
figure = prediction.plot_components(forecast)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b9b62d16bfad> in <module>
#       8 X['y'] = y
#       9 prediction = Prophet()
# ---> 10 prediction.fit(X)
#      11 future = prediction.make_future_dataframe(periods=240, freq='m')
#      12 forecast = prediction.predict(future)
#
# /opt/anaconda3/lib/python3.8/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1106         history = df[df['y'].notnull()].copy()
#    1107         if history.shape[0] < 2:
# -> 1108             raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1109         self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
#    1110
#
# ValueError: Dataframe has less than 2 non-NaN rows.

# %%
dates = []
magnitudes = []
count = 0
for i in range(0,23411):
    if (abs(X.loc[i].at["Latitude"]-24) <= 8) and (abs(-105-X.loc[i].at["Longitude"]) <= 11):
        dates.append(X.loc[i].at["Date"])
        magnitudes.append(X.loc[i].at["Magnitude"])
        count += 1
count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d6f9d37fefde> in <module>
#       3 count = 0
# ...

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from sklearn.model_selection import train_test_split
y = magnitudes
X = pd.DataFrame()
X['ds'] = pd.to_datetime(dates, utc=True)
X['ds'] = X['ds'].dt.tz_localize(None)
X['y'] = y
prediction = Prophet()
prediction.fit(X)
future = prediction.make_future_dataframe(periods=240, freq='m')
forecast = prediction.predict(future)
figure = prediction.plot(forecast)
figure = prediction.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dates = []
magnitudes = []
count = 0
for i in range(0,23411):
    if (abs(X.loc[i].at["Latitude"]-36) <= 5) and (abs(X.loc[i].at["Longitude"]-135.5) <= 5.5):
        dates.append(X.loc[i].at["Date"])
        magnitudes.append(X.loc[i].at["Magnitude"])
        count += 1
    if (abs(X.loc[i].at["Latitude"]-43) <= 2) and (abs(X.loc[i].at["Longitude"]-142.5) <= 2.5):
        dates.append(X.loc[i].at["Date"])
        magnitudes.append(X.loc[i].at["Magnitude"])
        count += 1
count
# Out:
# 530

# %%
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from sklearn.model_selection import train_test_split
y = magnitudes
X = pd.DataFrame()
X['ds'] = pd.to_datetime(dates, utc=True)
X['ds'] = X['ds'].dt.tz_localize(None)
X['y'] = y
prediction = Prophet()
prediction.fit(X)
future = prediction.make_future_dataframe(periods=240, freq='m')
forecast = prediction.predict(future)
figure = prediction.plot(forecast)
figure = prediction.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
